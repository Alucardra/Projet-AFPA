# %% [markdown]
# # Aide humanitaire

# %% [markdown]
# Faisons le point sur l’aide humanitaire internationale. Quels sont les grands enjeux actuels qui la traversent ? Avec le monde qui évolue, ce sont les méthodes et les besoins qui évoluent également.

# %% [markdown]
# Une personne sur deux vit avec 180euros par mois et une personne par quatre vit avec 164 euros par mois.En tant que datascientist, qui travaille pour un ONG de médecins du monde et qui doit analyser des données des différentes pays en difficulté économiques et sociales .

# %% [markdown]
# **Le but va être d’identifier les pays qui nécessitent une aide humanitaire prioritaire en créant des clusters.**

# %% [markdown]
# Pour commencer ,décomposer le projet en différentes étapes :
# - Import , nettoyage et visualisation
# - Préparer les données afin de les fournir aux algorithmes de machine learniing
# - Etc…

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_structure = pd.read_csv("Data_dictionary.csv")

df_structure.head(10)
# Out:
#   Column Name                                        Description
# 0     country                                Name of the country
# 1  child_mort  Death of children under 5 years of age per 100...
# 2     exports  Exports of goods and services. Given as %age o...
# 3      health         Total health spending as %age of Total GDP
# 4     imports  Imports of goods and services. Given as %age o...
# 5      Income                              Net income per person
# 6   Inflation  The measurement of the annual growth rate of t...
# 7  life_expec  The average number of years a new born child w...
# 8   total_fer  The number of children that would be born to e...
# 9        gdpp  The GDP per capita. Calculated as the Total GD...

# %%
df_country = pd.read_csv("Country_data.csv")
df_country.head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 6              Armenia        18.1     20.8    4.40     45.3    6700
# 7            Australia         4.8     19.8    8.73     20.9   41400
# 8              Austria         4.3     51.3   11.00     47.8   43200
# 9           Azerbaijan        39.2     54.3    5.88     20.7   16000
#
#    inflation  life_expec  total_fer   gdpp
# 0      9.440        56.2       5.82    553
# 1      4.490        76.3       1.65   4090
# 2     16.100        76.5       2.89   4460
# ...

# %%
df_country.tail(10)
# Out:
#                   country  child_mort  exports  health  imports  income  \
# 157  United Arab Emirates         8.6     77.7    3.66     63.6   57600
# 158        United Kingdom         5.2     28.2    9.64     30.8   36200
# 159         United States         7.3     12.4   17.90     15.8   49400
# 160               Uruguay        10.6     26.3    8.35     25.4   17100
# 161            Uzbekistan        36.3     31.7    5.81     28.5    4240
# 162               Vanuatu        29.2     46.6    5.25     52.7    2950
# 163             Venezuela        17.1     28.5    4.91     17.6   16500
# 164               Vietnam        23.3     72.0    6.84     80.2    4490
# 165                 Yemen        56.3     30.0    5.18     34.4    4480
# 166                Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 157      12.50        76.5       1.87  35000
# 158       1.57        80.3       1.92  38900
# ...
